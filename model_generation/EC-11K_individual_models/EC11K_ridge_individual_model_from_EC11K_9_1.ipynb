# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
import matplotlib
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score


# input file path
datasetdir = "D://indivdual_models//Dataset//2022_EC11K_single_drug"
resultdir = "D://indivdual_models//Result//Model_generation//2022_EC11K_single_drug"

# %%
drug_list = ["AEW541","Nilotinib","17-AAG","PHA-665752","Lapatinib","Nutlin-3"
            ,"AZD0530","PF2341066","L-685458","ZD-6474","Panobinostat","Sorafenib"
            ,"Irinotecan","Topotecan","LBW242","PD-0325901","PD-0332991","Paclitaxel"
            ,"PLX4720","RAF265","TAE684","TKI258","Erlotinib","AZD6244"]

# %%
from datetime import datetime
now = datetime.now()
day = now.strftime("%Y%m%d")
print("Starttime: " + day)

rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)
num = 1
for dname in drug_list:
    
    print('%s_//n' % dname)
    # read input file and index file for training and test set
    dataset = np.load(datasetdir + "//EC11K_%s.npz" % dname)
    ss0 = np.load(datasetdir + '//EC11K_%s_0_8_2.npz' % dname)

    # input and index file assign
    x = dataset['x']
    y = dataset['y']
    # y_linear = dataset['y_lnIC50']
    ss0_train = ss0['train']
    ss0_test = ss0['test']
    
    # z-normalization
    
    # training and test dataset assign
    train_X, train_y = x[ss0_train], y[ss0_train]
    test_X, test_y = x[ss0_test], y[ss0_test]
    
    from sklearn import preprocessing
    import pickle
    scaler = preprocessing.StandardScaler()
    train_X = scaler.fit_transform(train_X)
    pickle.dump(scaler, open(datasetdir + "//standardization_models//znorm_scaler_%s.pkl" % dname, 'wb'))
    test_X = scaler.transform(test_X)

    # data typing and the number of dataset
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    # train_X /= 255
    # test_X /= 255
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # model fitting
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)

    Ridge_regressor = Ridge(alpha=0.001)
    Ridge_regressor.fit(train_X,train_y)

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = Ridge_regressor.predict(test_X)
    predicted_value = predicted_classes

    import pickle
    import joblib
    joblib.dump(Ridge_regressor, resultdir + '//Ridge//EC11K_znorm_Ridge_%s.pkl' % dname) 
    
    # saving predicted ln(IC50)s and ln(IC50)s in the test set
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    c.to_csv(resultdir + '//Ridge//predicted_table//EC11K_Ridge_%s_pred_and_val_result.csv' % dname, index=False)

    # RMSE
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    
    # R-squared value
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 15},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=10)
    
    num += 1
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    

figdir = "D://indivdual_models//Result//Figure"
plt.savefig(figdir +'//EC11K_single_drug_Ridge_plot.png', dpi=400)
# Out:
# Starttime: 20221007
# AEW541_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:03.492542
# EndTime : 2022-10-07 15:16:03.532532
# AEW541’s final rmse value is = 0.827172
# AEW541 R-squared value is = -0.077824
# Nilotinib_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.52591e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (326, 18988)
# 326 train samples
# 81 test samples
# StartTime : 2022-10-07 15:16:03.903108
# EndTime : 2022-10-07 15:16:03.938177
# Nilotinib’s final rmse value is = 0.682056
# Nilotinib R-squared value is = -0.545248
# 17-AAG_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.54549e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:04.330844
# EndTime : 2022-10-07 15:16:04.363302
# 17-AAG’s final rmse value is = 1.248907
# 17-AAG R-squared value is = 0.152774
# PHA-665752_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=8.62088e-10): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:04.757438
# EndTime : 2022-10-07 15:16:04.792313
# PHA-665752’s final rmse value is = 0.850583
# PHA-665752 R-squared value is = -0.027464
# Lapatinib_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.06111e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:05.186150
# EndTime : 2022-10-07 15:16:05.227892
# Lapatinib’s final rmse value is = 0.652333
# Lapatinib R-squared value is = 0.379473
# Nutlin-3_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.03898e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:05.654635
# EndTime : 2022-10-07 15:16:05.695269
# Nutlin-3’s final rmse value is = 0.804480
# Nutlin-3 R-squared value is = -0.021942
# AZD0530_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.00753e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:06.112664
# EndTime : 2022-10-07 15:16:06.146767
# AZD0530’s final rmse value is = 0.798257
# AZD0530 R-squared value is = -0.270709
# PF2341066_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.28497e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:06.536979
# EndTime : 2022-10-07 15:16:06.587836
# PF2341066’s final rmse value is = 0.604329
# PF2341066 R-squared value is = 0.168523
# L-685458_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.11221e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (383, 18988)
# 383 train samples
# 95 test samples
# StartTime : 2022-10-07 15:16:07.017197
# EndTime : 2022-10-07 15:16:07.056093
# L-685458’s final rmse value is = 0.671685
# L-685458 R-squared value is = 0.193558
# ZD-6474_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.17446e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2022-10-07 15:16:07.472617
# EndTime : 2022-10-07 15:16:07.517464
# ZD-6474’s final rmse value is = 0.777092
# ZD-6474 R-squared value is = 0.056149
# Panobinostat_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.37656e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (390, 18988)
# 390 train samples
# 97 test samples
# StartTime : 2022-10-07 15:16:07.962817
# EndTime : 2022-10-07 15:16:08.002820
# Panobinostat’s final rmse value is = 0.622923
# Panobinostat R-squared value is = 0.470478
# Sorafenib_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.29166e-10): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:08.420253
# EndTime : 2022-10-07 15:16:08.466456
# Sorafenib’s final rmse value is = 0.785623
# Sorafenib R-squared value is = -0.237588
# Irinotecan_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=7.58574e-10): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (245, 18988)
# 245 train samples
# 61 test samples
# StartTime : 2022-10-07 15:16:08.733679
# EndTime : 2022-10-07 15:16:08.757668
# Irinotecan’s final rmse value is = 1.200683
# Irinotecan R-squared value is = 0.075283
# Topotecan_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=2.07955e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:09.174315
# EndTime : 2022-10-07 15:16:09.219054
# Topotecan’s final rmse value is = 1.298160
# Topotecan R-squared value is = 0.265662
# LBW242_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=7.18628e-10): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:09.636054
# EndTime : 2022-10-07 15:16:09.688051
# LBW242’s final rmse value is = 0.472465
# LBW242 R-squared value is = -2.144177
# PD-0325901_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.57139e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:10.176098
# EndTime : 2022-10-07 15:16:10.227247
# PD-0325901’s final rmse value is = 1.631838
# PD-0325901 R-squared value is = 0.407561
# PD-0332991_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.06166e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (337, 18988)
# 337 train samples
# 84 test samples
# StartTime : 2022-10-07 15:16:10.609663
# EndTime : 2022-10-07 15:16:10.648559
# PD-0332991’s final rmse value is = 0.529151
# PD-0332991 R-squared value is = 0.265291
# Paclitaxel_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.02554e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:11.086084
# EndTime : 2022-10-07 15:16:11.136103
# Paclitaxel’s final rmse value is = 2.282376
# Paclitaxel R-squared value is = -0.003590
# PLX4720_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.03457e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2022-10-07 15:16:11.578592
# EndTime : 2022-10-07 15:16:11.647338
# PLX4720’s final rmse value is = 0.576746
# PLX4720 R-squared value is = 0.260144
# RAF265_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.01925e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (358, 18988)
# 358 train samples
# 89 test samples
# StartTime : 2022-10-07 15:16:12.045741
# EndTime : 2022-10-07 15:16:12.081803
# RAF265’s final rmse value is = 1.067076
# RAF265 R-squared value is = 0.294336
# TAE684_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=9.84649e-10): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:12.530060
# EndTime : 2022-10-07 15:16:12.570968
# TAE684’s final rmse value is = 1.222898
# TAE684 R-squared value is = 0.201613
# TKI258_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.16234e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:13.021237
# EndTime : 2022-10-07 15:16:13.069281
# TKI258’s final rmse value is = 0.699855
# TKI258 R-squared value is = -0.009828
# Erlotinib_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=9.65127e-10): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:13.526328
# EndTime : 2022-10-07 15:16:13.571675
# Erlotinib’s final rmse value is = 0.623568
# Erlotinib R-squared value is = -0.269862
# AZD6244_//n
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.46567e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:14.008734
# EndTime : 2022-10-07 15:16:14.054582
# AZD6244’s final rmse value is = 1.136689
# AZD6244 R-squared value is = 0.377797
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=1.47563e-09): result may not be accurate.
#   overwrite_a=False)

# %%
num
# Out:
# 25

# %%
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         AEW541  0.827172 -0.077824
# 1      Nilotinib  0.682056 -0.545248
# 2         17-AAG  1.248907  0.152774
# 3     PHA-665752  0.850583 -0.027464
# 4      Lapatinib  0.652333  0.379473
# 5       Nutlin-3  0.804480 -0.021942
# 6        AZD0530  0.798257 -0.270709
# 7      PF2341066  0.604329  0.168523
# 8       L-685458  0.671685  0.193558
# 9        ZD-6474  0.777092  0.056149
# 10  Panobinostat  0.622923  0.470478
# 11     Sorafenib  0.785623 -0.237588
# 12    Irinotecan  1.200683  0.075283
# 13     Topotecan  1.298160  0.265662
# 14        LBW242  0.472465 -2.144177
# 15    PD-0325901  1.631838  0.407561
# 16    PD-0332991  0.529151  0.265291
# 17    Paclitaxel  2.282376 -0.003590
# 18       PLX4720  0.576746  0.260144
# 19        RAF265  1.067076  0.294336
# 20        TAE684  1.222898  0.201613
# 21        TKI258  0.699855 -0.009828
# 22     Erlotinib  0.623568 -0.269862
# 23       AZD6244  1.136689  0.377797

# %%
result.to_csv(resultdir +'//EC11K_Ridge_24drugs_metrics.csv', index=False)
