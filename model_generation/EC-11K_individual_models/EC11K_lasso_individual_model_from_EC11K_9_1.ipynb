# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
import matplotlib
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score

# input file path
datasetdir = "D://indivdual_models//Dataset//2022_EC11K_single_drug"
resultdir = "D://indivdual_models//Result//Model_generation//2022_EC11K_single_drug"

# %%
drug_list = ["AEW541","Nilotinib","17-AAG","PHA-665752","Lapatinib","Nutlin-3"
            ,"AZD0530","PF2341066","L-685458","ZD-6474","Panobinostat","Sorafenib"
            ,"Irinotecan","Topotecan","LBW242","PD-0325901","PD-0332991","Paclitaxel"
            ,"PLX4720","RAF265","TAE684","TKI258","Erlotinib","AZD6244"]

# %%
from datetime import datetime
now = datetime.now()
day = now.strftime("%Y%m%d")
print("Starttime: " + day)

rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)
num = 1
for dname in drug_list:
    
    print('%s_//n' % dname)
    # read input file and index file for training and test set
    dataset = np.load(datasetdir + "//EC11K_%s.npz" % dname)
    ss0 = np.load(datasetdir + '//EC11K_%s_0_8_2.npz' % dname)

    # input and index file assign
    x = dataset['x']
    y = dataset['y']
    # y_linear = dataset['y_lnIC50']
    ss0_train = ss0['train']
    ss0_test = ss0['test']
    
    # z-normalization
    
    # training and test dataset assign
    train_X, train_y = x[ss0_train], y[ss0_train]
    test_X, test_y = x[ss0_test], y[ss0_test]
    
    from sklearn import preprocessing
    import pickle
    scaler = preprocessing.StandardScaler()
    train_X = scaler.fit_transform(train_X)
    pickle.dump(scaler, open(datasetdir + "//standardization_models//znorm_scaler_%s.pkl" % dname, 'wb'))
    test_X = scaler.transform(test_X)

    # data typing and the number of dataset
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    # train_X /= 255
    # test_X /= 255
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # model fitting
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)

    lasso_regressor = Lasso(alpha=0.001)
    lasso_regressor.fit(train_X,train_y)

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = lasso_regressor.predict(test_X)
    predicted_value = predicted_classes

    import pickle
    import joblib
    joblib.dump(lasso_regressor, resultdir + '//Lasso//EC11K_znorm_Lasso_%s.pkl' % dname) 
    
    # saving predicted ln(IC50)s and ln(IC50)s in the test set
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    c.to_csv(resultdir + '//Lasso//predicted_table//EC11K_Lasso_%s_pred_and_val_result.csv' % dname, index=False)

    # RMSE
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    
    # R-squared value
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 15},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=10)
    
    num += 1
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    

figdir = "D://indivdual_models//Result//Figure"
plt.savefig(figdir +'//EC11K_single_drug_lasso_plot.png', dpi=400)
# Out:
# Starttime: 20221007
# AEW541_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:09.794255
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12960851192474365, tolerance: 0.02689383551478386
#   positive)
# EndTime : 2022-10-07 15:16:12.596609
# AEW541’s final rmse value is = 0.919835
# AEW541 R-squared value is = -0.332834
# Nilotinib_//n
# train_X shape: (326, 18988)
# 326 train samples
# 81 test samples
# StartTime : 2022-10-07 15:16:13.045247
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23926612734794617, tolerance: 0.03656727075576782
#   positive)
# EndTime : 2022-10-07 15:16:15.159928
# Nilotinib’s final rmse value is = 0.698306
# Nilotinib R-squared value is = -0.619756
# 17-AAG_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:15.556402
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5889191031455994, tolerance: 0.09284303337335587
#   positive)
# EndTime : 2022-10-07 15:16:17.827809
# 17-AAG’s final rmse value is = 1.265542
# 17-AAG R-squared value is = 0.130054
# PHA-665752_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:18.269053
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007136769592761993, tolerance: 0.004862528759986162
#   positive)
# EndTime : 2022-10-07 15:16:20.556273
# PHA-665752’s final rmse value is = 0.880448
# PHA-665752 R-squared value is = -0.100880
# Lapatinib_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:20.926095
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2760074734687805, tolerance: 0.02355622500181198
#   positive)
# EndTime : 2022-10-07 15:16:23.081066
# Lapatinib’s final rmse value is = 0.803469
# Lapatinib R-squared value is = 0.058630
# Nutlin-3_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:23.481841
# EndTime : 2022-10-07 15:16:25.308866
# Nutlin-3’s final rmse value is = 0.811027
# Nutlin-3 R-squared value is = -0.038642
# AZD0530_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:25.700888
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11559344828128815, tolerance: 0.027801768854260445
#   positive)
# EndTime : 2022-10-07 15:16:27.875215
# AZD0530’s final rmse value is = 0.865799
# AZD0530 R-squared value is = -0.494841
# PF2341066_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:28.259194
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.30334752798080444, tolerance: 0.02638428844511509
#   positive)
# EndTime : 2022-10-07 15:16:30.412148
# PF2341066’s final rmse value is = 0.615517
# PF2341066 R-squared value is = 0.137452
# L-685458_//n
# train_X shape: (383, 18988)
# 383 train samples
# 95 test samples
# StartTime : 2022-10-07 15:16:30.779886
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13476045429706573, tolerance: 0.014941866509616375
#   positive)
# EndTime : 2022-10-07 15:16:33.002024
# L-685458’s final rmse value is = 0.724066
# L-685458 R-squared value is = 0.062875
# ZD-6474_//n
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2022-10-07 15:16:33.378027
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10062487423419952, tolerance: 0.02373124659061432
#   positive)
# EndTime : 2022-10-07 15:16:35.467767
# ZD-6474’s final rmse value is = 0.799098
# ZD-6474 R-squared value is = 0.001935
# Panobinostat_//n
# train_X shape: (390, 18988)
# 390 train samples
# 97 test samples
# StartTime : 2022-10-07 15:16:35.861012
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3363697826862335, tolerance: 0.029780132696032524
#   positive)
# EndTime : 2022-10-07 15:16:37.986357
# Panobinostat’s final rmse value is = 0.729132
# Panobinostat R-squared value is = 0.274516
# Sorafenib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:38.379340
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13498125970363617, tolerance: 0.016495931893587112
#   positive)
# EndTime : 2022-10-07 15:16:40.553210
# Sorafenib’s final rmse value is = 0.849819
# Sorafenib R-squared value is = -0.448106
# Irinotecan_//n
# train_X shape: (245, 18988)
# 245 train samples
# 61 test samples
# StartTime : 2022-10-07 15:16:40.799766
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3235902190208435, tolerance: 0.043914224952459335
#   positive)
# EndTime : 2022-10-07 15:16:42.265847
# Irinotecan’s final rmse value is = 1.180439
# Irinotecan R-squared value is = 0.106202
# Topotecan_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:42.647304
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7295295000076294, tolerance: 0.09894078224897385
#   positive)
# EndTime : 2022-10-07 15:16:45.007714
# Topotecan’s final rmse value is = 1.354925
# Topotecan R-squared value is = 0.200036
# LBW242_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:45.406552
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11531874537467957, tolerance: 0.035194031894207
#   positive)
# EndTime : 2022-10-07 15:16:47.564317
# LBW242’s final rmse value is = 0.645251
# LBW242 R-squared value is = -4.864406
# PD-0325901_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:47.945875
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6378660202026367, tolerance: 0.19475968182086945
#   positive)
# EndTime : 2022-10-07 15:16:50.290063
# PD-0325901’s final rmse value is = 1.716462
# PD-0325901 R-squared value is = 0.344522
# PD-0332991_//n
# train_X shape: (337, 18988)
# 337 train samples
# 84 test samples
# StartTime : 2022-10-07 15:16:50.625131
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04950866103172302, tolerance: 0.01153138279914856
#   positive)
# EndTime : 2022-10-07 15:16:52.506741
# PD-0332991’s final rmse value is = 0.617202
# PD-0332991 R-squared value is = 0.000434
# Paclitaxel_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:16:52.887733
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1713920831680298, tolerance: 0.15771916508674622
#   positive)
# EndTime : 2022-10-07 15:16:55.096689
# Paclitaxel’s final rmse value is = 2.195677
# Paclitaxel R-squared value is = 0.071207
# PLX4720_//n
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2022-10-07 15:16:55.542451
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0922946110367775, tolerance: 0.014867817051708698
#   positive)
# EndTime : 2022-10-07 15:16:57.885381
# PLX4720’s final rmse value is = 0.608664
# PLX4720 R-squared value is = 0.175989
# RAF265_//n
# train_X shape: (358, 18988)
# 358 train samples
# 89 test samples
# StartTime : 2022-10-07 15:16:58.270225
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3332580626010895, tolerance: 0.04663737118244171
#   positive)
# EndTime : 2022-10-07 15:17:00.349184
# RAF265’s final rmse value is = 1.205990
# RAF265 R-squared value is = 0.098649
# TAE684_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:17:00.744204
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.35203951597213745, tolerance: 0.04172133281826973
#   positive)
# EndTime : 2022-10-07 15:17:03.036523
# TAE684’s final rmse value is = 1.399726
# TAE684 R-squared value is = -0.045970
# TKI258_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2022-10-07 15:17:03.442811
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11902152001857758, tolerance: 0.023246360942721367
#   positive)
# EndTime : 2022-10-07 15:17:05.767251
# TKI258’s final rmse value is = 0.806355
# TKI258 R-squared value is = -0.340552
# Erlotinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:17:06.168642
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11050385236740112, tolerance: 0.021177014335989952
#   positive)
# EndTime : 2022-10-07 15:17:08.306511
# Erlotinib’s final rmse value is = 0.718953
# Erlotinib R-squared value is = -0.688069
# AZD6244_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2022-10-07 15:17:08.702353
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5451383590698242, tolerance: 0.08731985092163086
#   positive)
# EndTime : 2022-10-07 15:17:10.833819
# AZD6244’s final rmse value is = 1.276167
# AZD6244 R-squared value is = 0.215733

# %%
now = datetime.now()
day = now.strftime("%Y%m%d")
print("Finished time: " + day)
# Out:
# Finished time: 20221007

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         AEW541  0.919835 -0.332834
# 1      Nilotinib  0.698306 -0.619756
# 2         17-AAG  1.265542  0.130054
# 3     PHA-665752  0.880448 -0.100880
# 4      Lapatinib  0.803469  0.058630
# 5       Nutlin-3  0.811027 -0.038642
# 6        AZD0530  0.865799 -0.494841
# 7      PF2341066  0.615517  0.137452
# 8       L-685458  0.724066  0.062875
# 9        ZD-6474  0.799098  0.001935
# 10  Panobinostat  0.729132  0.274516
# 11     Sorafenib  0.849819 -0.448106
# 12    Irinotecan  1.180439  0.106202
# 13     Topotecan  1.354925  0.200036
# 14        LBW242  0.645251 -4.864406
# 15    PD-0325901  1.716462  0.344522
# 16    PD-0332991  0.617202  0.000434
# 17    Paclitaxel  2.195677  0.071207
# 18       PLX4720  0.608664  0.175989
# 19        RAF265  1.205990  0.098649
# 20        TAE684  1.399726 -0.045970
# 21        TKI258  0.806355 -0.340552
# 22     Erlotinib  0.718953 -0.688069
# 23       AZD6244  1.276167  0.215733

# %%
result.to_csv(resultdir +'//EC11K_Lasso_24drugs_metrics.csv', index=False)
